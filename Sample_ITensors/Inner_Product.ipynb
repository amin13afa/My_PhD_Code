# %%
using ITensors

# %%
# Inner product computation
# Yellow parameters
N = 2;
a = 1;
m₀ = 1;
g₀ = 1;
r = 1;
sites = siteinds("Fermion",N)
ampo = OpSum()
############################ First term of our Hamiltonian
# In our notation odd sites are related to subscripts 1
for j in 1:2:N-2
    ampo += 1im/(2a),"C",j,"Cdag",j+2
    ampo += -1im/(2a),"C",j+2,"Cdag",j
end 
########################### Second term of Hamiltonian 
# In our notation even sites are related to subscripts 0
for j in 2:2:N-2
    ampo += -1im/(2a),"C",j,"Cdag",j+2
    ampo += 1im/(2a),"C",j+2,"Cdag",j
end
########################## Third part of Hamiltonian 
for j in 1:N-1
    ampo += -1im*m₀,"Cdag",j,"Cdag",j+1
    ampo += 1im*m₀,"C",j+1,"C",j
end 
######################### 
# Computation of H_g
for j in 1:2:N-1
    ampo += (g₀)/(2a),"C*C",j+1,"Cdag*Cdag",j
    ampo += (g₀)/(2a),"Cdag*Cdag",j+1,"C*C",j          
    ampo -= (g₀)/(2a),"C*Cdag",j+1,"Cdag*C",j          
    ampo -= (g₀)/(2a),"Cdag*C",j+1,"C*Cdag",j
end
############################
# Computing Wilson term 
 for j in 1:N-1
    ampo += 1im*r/(2a),"C",j,"Cdag",j+1
    ampo += -1im*r/(2a),"C",j+1,"Cdag",j
end 
for j in 1:2:N-1
    ampo += -2im,"Cdag",j+1,"C",j
    ampo += 2im,"Cdag",j,"C",j+1
end
for j in 1:2:N-3
    ampo += 1im*r/(2a),"Cdag",j,"C",j+3
    ampo += -1im*r/(2a),"Cdag",j+3,"C",j
end


Hy = MPO(ampo, sites)
psi₀ = randomMPS(sites,10)
sweep = Sweeps(10)
setmaxdim!(sweep,repeat([10],10)... )
# sweep = Sweeps(3)
# setmaxdim!(sweep, 10,10,20)
setcutoff!(sweep, 1E-10)
e2, psi2 = dmrg(Hy,psi₀,sweep);
# Out:
# After sweep 1 energy=-2.998772544719 maxlinkdim=2 maxerr=0.00E+00 time=0.001
# After sweep 2 energy=-2.999999920965 maxlinkdim=2 maxerr=0.00E+00 time=0.001
# After sweep 3 energy=-2.999999999995 maxlinkdim=2 maxerr=0.00E+00 time=0.001
# After sweep 4 energy=-3.000000000000 maxlinkdim=2 maxerr=0.00E+00 time=0.002
# After sweep 5 energy=-3.000000000000 maxlinkdim=2 maxerr=0.00E+00 time=0.002
# After sweep 6 energy=-3.000000000000 maxlinkdim=2 maxerr=0.00E+00 time=0.001
# After sweep 7 energy=-3.000000000000 maxlinkdim=2 maxerr=0.00E+00 time=0.002
# After sweep 8 energy=-3.000000000000 maxlinkdim=2 maxerr=0.00E+00 time=0.001
# After sweep 9 energy=-3.000000000000 maxlinkdim=2 maxerr=0.00E+00 time=0.001
# After sweep 10 energy=-3.000000000000 maxlinkdim=2 maxerr=0.00E+00 time=0.001

# %%
# Inner product computation

N = 3;
a = 1;
m₀ = 1;
g₀ = 1;
r = 1;
sites = siteinds("Fermion",N)
ampo = OpSum()
############################ First term of our Hamiltonian
# In our notation odd sites are related to subscripts 1
for j in 1:2:N-2
    ampo += 1im/(2a),"C",j,"Cdag",j+2
    ampo += -1im/(2a),"C",j+2,"Cdag",j
end 
########################### Second term of Hamiltonian 
# In our notation even sites are related to subscripts 0
for j in 2:2:N-2
    ampo += -1im/(2a),"C",j,"Cdag",j+2
    ampo += 1im/(2a),"C",j+2,"Cdag",j
end
########################## Third part of Hamiltonian 
for j in 1:N-1
    ampo += -1im*m₀,"Cdag",j,"Cdag",j+1
    ampo += 1im*m₀,"C",j+1,"C",j
end 
######################### 
# Computation of H_g
for j in 1:2:N-1
    ampo += (g₀)/(2a),"C*C",j+1,"Cdag*Cdag",j
    ampo += (g₀)/(2a),"Cdag*Cdag",j+1,"C*C",j          
    ampo -= (g₀)/(2a),"C*Cdag",j+1,"Cdag*C",j          
    ampo -= (g₀)/(2a),"Cdag*C",j+1,"C*Cdag",j
end
############################
# Computing Wilson term 
 for j in 1:N-1
    ampo += 1im*r/(2a),"C",j,"Cdag",j+1
    ampo += -1im*r/(2a),"C",j+1,"Cdag",j
end 
for j in 1:2:N-1
    ampo += -2im,"Cdag",j+1,"C",j
    ampo += 2im,"Cdag",j,"C",j+1
end
for j in 1:2:N-3
    ampo += 1im*r/(2a),"Cdag",j,"C",j+3
    ampo += -1im*r/(2a),"Cdag",j+3,"C",j
end


Hy = MPO(ampo, sites)
psi₀ = randomMPS(sites,10)
sweep = Sweeps(10)
setmaxdim!(sweep,repeat([10],10)... )
# sweep = Sweeps(3)
# setmaxdim!(sweep, 10,10,20)
setcutoff!(sweep, 1E-10)
e3, psi3 = dmrg(Hy,psi₀,sweep);
# Out:
# After sweep 1 energy=-3.212444955700 maxlinkdim=2 maxerr=1.11E-15 time=0.002
# After sweep 2 energy=-3.212445275250 maxlinkdim=2 maxerr=9.99E-16 time=0.003
# After sweep 3 energy=-3.212445275250 maxlinkdim=2 maxerr=8.88E-16 time=0.003
# After sweep 4 energy=-3.212445275250 maxlinkdim=2 maxerr=8.88E-16 time=0.004
# After sweep 5 energy=-3.212445275250 maxlinkdim=2 maxerr=6.66E-17 time=0.003
# After sweep 6 energy=-3.212445275250 maxlinkdim=2 maxerr=1.05E-15 time=0.003
# After sweep 7 energy=-3.212445275250 maxlinkdim=2 maxerr=9.99E-16 time=0.002
# After sweep 8 energy=-3.212445275250 maxlinkdim=2 maxerr=1.11E-15 time=0.002
# After sweep 9 energy=-3.212445275250 maxlinkdim=2 maxerr=1.28E-15 time=0.002
# After sweep 10 energy=-3.212445275250 maxlinkdim=2 maxerr=9.99E-16 time=0.002
